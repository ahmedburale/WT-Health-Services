# %% [markdown]
# # Health Services Analysis

# %%
import numpy as np
import pandas as pd

# %%
# Set random seed for reproducibility
np.random.seed(42)

# Number of records
n_records = 5000

# %%
# Generate synthetic data
data = {
    'patient_id': np.arange(1, n_records + 1),
    'age': np.random.randint(18, 90, size=n_records),
    'gender': np.random.choice(['Male', 'Female'], size=n_records),
    'procedure_type': np.random.choice(['Type A', 'Type B', 'Type C'], size=n_records),
    'priority_level': np.random.choice(['High', 'Medium', 'Low'], size=n_records),
    'waiting_time_days': np.random.normal(loc=60, scale=15, size=n_records).astype(int),
    'scheduled_delay_days': np.random.normal(loc=10, scale=5, size=n_records).astype(int),
    'unplanned_emergency': np.random.choice([0, 1], size=n_records, p=[0.8, 0.2]),
    'outcome': np.random.choice(['Successful', 'Complication', 'Death'], size=n_records, p=[0.85, 0.1, 0.05])
}

# %%
# Create DataFrame
df = pd.DataFrame(data)
print(df.to_csv())
# Out:
# ,patient_id,age,gender,procedure_type,priority_level,waiting_time_days,scheduled_delay_days,unplanned_emergency,outcome
# 0,1,69,Male,Type C,Low,53,16,0,Death
# 1,2,32,Female,Type C,Medium,37,-2,0,Successful
# 2,3,89,Male,Type B,Low,25,6,0,Successful
# 3,4,78,Male,Type A,Low,43,7,0,Successful
# 4,5,38,Male,Type A,High,36,-4,0,Successful
# 5,6,41,Male,Type B,High,65,3,0,Successful
# 6,7,20,Female,Type C,Medium,52,13,0,Successful
# 7,8,39,Female,Type A,Medium,51,10,0,Successful
# 8,9,70,Male,Type B,Medium,45,17,0,Successful
# 9,10,19,Male,Type B,Medium,11,17,1,Complication
# 10,11,47,Female,Type A,Low,82,12,0,Successful
# 11,12,55,Female,Type A,Medium,44,11,0,Successful
# 12,13,19,Female,Type C,Low,53,10,0,Successful
# 13,14,81,Male,Type C,High,38,-3,0,Successful
# 14,15,77,Female,Type A,Medium,74,3,0,Successful
# 15,16,38,Male,Type C,High,62,10,1,Successful
# 16,17,50,Male,Type B,High,47,13,0,Successful
# 17,18,75,Female,Type C,Low,54,11,0,Successful
# 18,19,39,Male,Type C,Medium,85,5,0,Successful
# 19,20,66,Female,Type B,Low,58,14,0,Complication
# 20,21,76,Male,Type C,High,57,17,1,Successful
# 21,22,59,Female,Type B,Medium,45,14,0,Successful
# 22,23,77,Male,Type C,High,31,14,1,Complication
# 23,24,32,Male,Type A,High,57,7,1,Successful
# 24,25,79,Female,Type C,Medium,64,15,0,Successful
# 25,26,79,Female,Type A,Medium,76,10,0,Successful
# 26,27,64,Female,Type A,Medium,26,12,0,Successful
# 27,28,79,Female,Type A,Low,43,11,1,Successful
# 28,29,68,Male,Type A,Low,51,9,0,Successful
# 29,30,72,Female,Type A,High,59,5,0,Successful
# 30,31,81,Female,Type B,Medium,57,9,0,Successful
# 31,32,20,Male,Type B,High,58,14,0,Successful
# 32,33,68,Female,Type B,High,66,7,1,Complication
# 33,34,24,Female,Type A,High,46,14,0,Successful
# 34,35,38,Male,Type C,High,74,13,0,Successful
# 35,36,56,Female,Type B,High,66,8,0,Successful
# 36,37,35,Female,Type C,Medium,55,16,0,Successful
# 37,38,21,Female,Type C,Low,84,8,0,Successful
# 38,39,77,Female,Type A,Medium,83,17,0,Successful
# 39,40,31,Female,Type A,Medium,73,12,0,Successful
# 40,41,26,Female,Type A,Medium,14,9,0,Successful
# 41,42,70,Male,Type B,Low,83,5,0,Successful
# 42,43,19,Female,Type A,Low,71,9,0,Successful
# 43,44,77,Male,Type B,Low,90,8,1,Successful
# 44,45,88,Male,Type B,Medium,78,3,1,Successful
# 45,46,61,Male,Type B,Low,83,8,0,Successful
# 46,47,25,Male,Type B,High,73,5,0,Complication
# 47,48,64,Female,Type A,Low,80,12,1,Successful
# 48,49,52,Female,Type B,Medium,89,16,0,Complication
# 49,50,53,Female,Type A,Medium,63,3,1,Successful
# 50,51,67,Male,Type A,High,36,18,1,Successful
# 51,52,21,Female,Type B,Low,55,9,0,Successful
# 52,53,19,Female,Type A,Low,65,5,0,Successful
# 53,54,23,Female,Type C,High,61,13,0,Successful
# 54,55,71,Male,Type A,Medium,41,7,0,Successful
# 55,56,21,Male,Type A,Medium,35,9,1,Successful
# 56,57,71,Female,Type B,Low,48,7,1,Successful
# 57,58,80,Male,Type B,Low,72,5,0,Successful
# 58,59,35,Male,Type A,Low,83,13,0,Successful
# 59,60,61,Female,Type B,Low,73,8,0,Death
# 60,61,51,Male,Type C,Low,75,2,0,Successful
# 61,62,79,Male,Type C,Medium,58,12,0,Successful
# 62,63,31,Female,Type B,Medium,33,3,1,Successful
# 63,64,65,Male,Type A,Medium,53,4,0,Complication
# 64,65,32,Male,Type C,Medium,56,15,0,Successful
# 65,66,89,Male,Type C,High,52,4,0,Successful
# 66,67,79,Male,Type A,Medium,60,-1,0,Successful
# 67,68,57,Male,Type B,High,66,13,0,Successful
# 68,69,70,Male,Type C,Medium,72,8,0,Complication
# 69,70,41,Male,Type A,Low,55,8,0,Successful
# 70,71,43,Male,Type A,Low,31,8,0,Successful
# 71,72,77,Female,Type C,Low,52,11,0,Successful
# 72,73,58,Female,Type B,High,60,6,0,Successful
# 73,74,46,Female,Type C,Medium,78,17,1,Death
# 74,75,32,Female,Type A,Medium,51,2,1,Death
# 75,76,62,Male,Type C,High,67,12,0,Successful
# 76,77,82,Female,Type B,High,64,13,0,Successful
# 77,78,88,Female,Type A,High,60,6,1,Successful
# 78,79,26,Male,Type B,High,73,4,0,Successful
# 79,80,18,Male,Type C,High,50,15,0,Complication
# 80,81,25,Male,Type C,Low,51,5,0,Successful
# 81,82,80,Male,Type B,Medium,59,6,0,Successful
# 82,83,28,Male,Type C,High,50,14,0,Successful
# 83,84,25,Female,Type B,Low,67,10,0,Successful
# 84,85,52,Male,Type C,High,49,1,0,Complication
# 85,86,52,Female,Type B,Low,63,18,1,Successful
# 86,87,50,Female,Type B,High,58,7,1,Successful
# 87,88,22,Male,Type A,Medium,63,7,0,Successful
# 88,89,58,Female,Type A,High,53,11,0,Successful
# 89,90,45,Female,Type B,High,54,13,0,Successful
# 90,91,24,Male,Type C,Medium,61,19,0,Successful
# 91,92,89,Female,Type C,Medium,63,1,0,Successful
# 92,93,29,Female,Type C,High,59,14,0,Successful
# 93,94,51,Female,Type B,Medium,85,13,0,Death
# 94,95,50,Male,Type B,Medium,45,9,0,Death
# 95,96,65,Male,Type B,Low,59,13,0,Successful
# 96,97,40,Male,Type B,Medium,36,14,1,Successful
# 97,98,79,Female,Type A,Medium,65,3,0,Death
# 98,99,54,Male,Type B,High,43,18,1,Successful
# 99,100,61,Female,Type C,High,55,2,1,Successful
# 100,101,52,Male,Type A,Low,54,4,0,Successful
# 101,102,82,Female,Type C,High,64,8,0,Death
# 102,103,64,Male,Type B,Medium,51,19,0,Successful
# 103,104,20,Male,Type A,Medium,51,8,0,Successful
# 104,105,18,Female,Type B,Medium,81,9,0,Successful
# 105,106,22,Male,Type A,High,64,17,0,Successful
# 106,107,31,Female,Type C,Medium,51,8,0,Successful
# 107,108,44,Male,Type B,Medium,56,4,0,Death
# 108,109,26,Male,Type B,Low,84,7,0,Successful
# 109,110,32,Female,Type A,Low,56,16,0,Successful
# 110,111,59,Female,Type A,Low,49,10,0,Death
# 111,112,68,Female,Type B,High,49,19,0,Successful
# 112,113,80,Male,Type A,Medium,51,13,0,Successful
# 113,114,69,Female,Type B,Medium,51,6,1,Successful
# 114,115,21,Male,Type A,Medium,40,10,0,Successful
# 115,116,40,Female,Type C,Low,43,5,0,Successful
# 116,117,32,Female,Type A,Medium,47,6,0,Death
# 117,118,60,Female,Type C,Medium,68,32,0,Successful
# 118,119,46,Female,Type A,Medium,54,15,0,Successful
# 119,120,53,Female,Type A,Medium,56,14,0,Successful
# 120,121,30,Female,Type B,Medium,79,6,1,Successful
# 121,122,49,Male,Type A,High,79,17,0,Successful
# 122,123,88,Female,Type A,Medium,55,15,0,Complication
# 123,124,76,Male,Type C,High,50,19,0,Successful
# 124,125,45,Female,Type A,Medium,47,19,0,Successful
# 125,126,83,Female,Type B,High,70,2,0,Successful
# 126,127,59,Female,Type C,Medium,56,4,0,Successful
# 127,128,62,Male,Type B,Medium,54,4,1,Successful
# 128,129,79,Male,Type B,Medium,47,5,0,Successful
# 129,130,74,Female,Type B,Medium,48,11,0,Successful
# 130,131,23,Male,Type B,Low,64,7,0,Successful
# 131,132,45,Female,Type C,Medium,40,20,0,Complication
# 132,133,45,Female,Type A,High,74,19,1,Successful
# 133,134,61,Male,Type B,Low,51,9,0,Successful
# 134,135,47,Male,Type C,Low,57,19,0,Successful
# 135,136,79,Male,Type B,Medium,39,17,1,Successful
# 136,137,79,Male,Type A,High,59,7,0,Complication
# 137,138,18,Female,Type C,High,55,0,0,Successful
# 138,139,44,Male,Type C,Low,59,8,0,Successful
# 139,140,79,Male,Type A,High,82,6,0,Successful
# 140,141,20,Female,Type C,Medium,62,11,0,Successful
# 141,142,87,Male,Type A,Medium,48,10,0,Successful
# 142,143,89,Male,Type C,Medium,49,10,1,Successful
# 143,144,44,Male,Type C,Medium,68,12,0,Successful
# 144,145,26,Male,Type A,Medium,79,3,1,Successful
# 145,146,79,Female,Type A,Low,64,12,0,Successful
# 146,147,54,Female,Type C,Medium,70,7,0,Successful
# 147,148,68,Male,Type C,Medium,69,10,0,Successful
# 148,149,61,Male,Type A,Low,81,14,1,Successful
# 149,150,41,Female,Type A,Low,30,3,0,Successful
# 150,151,76,Male,Type C,Low,70,8,0,Successful
# 151,152,49,Male,Type C,High,74,9,0,Successful
# 152,153,69,Male,Type C,High,39,7,1,Successful
# 153,154,79,Male,Type A,Medium,46,14,1,Successful
# 154,155,75,Male,Type C,Medium,47,6,0,Successful
# 155,156,69,Male,Type B,Medium,49,7,0,Complication
# 156,157,29,Male,Type A,High,52,6,0,Successful
# 157,158,56,Male,Type C,Medium,63,15,1,Successful
# 158,159,19,Male,Type A,Medium,72,7,0,Successful
# 159,160,20,Female,Type B,High,76,12,0,Complication
# 160,161,73,Female,Type A,Low,47,19,1,Successful
# 161,162,76,Female,Type C,High,47,9,0,Successful
# 162,163,19,Male,Type B,Medium,79,15,0,Successful
# 163,164,19,Male,Type B,High,69,18,0,Complication
# 164,165,71,Female,Type C,Low,61,15,0,Successful
# 165,166,18,Male,Type C,Low,67,9,0,Successful
# 166,167,36,Female,Type C,Low,59,13,0,Successful
# 167,168,19,Male,Type A,Low,67,3,0,Successful
# 168,169,70,Female,Type A,Low,54,6,0,Successful
# 169,170,61,Female,Type A,Low,64,6,0,Successful
# 170,171,49,Female,Type C,Medium,37,21,1,Complication
# 171,172,87,Male,Type C,Medium,49,5,0,Successful
# 172,173,49,Female,Type A,High,49,5,0,Successful
# 173,174,85,Male,Type B,Medium,54,4,0,Successful
# 174,175,72,Male,Type A,Low,46,12,0,Complication
# 175,176,73,Male,Type B,Medium,51,10,1,Complication
# 176,177,34,Male,Type C,High,37,15,0,Successful
# 177,178,55,Male,Type C,Low,68,13,0,Successful
# 178,179,41,Male,Type A,Medium,58,3,1,Successful
# 179,180,86,Male,Type A,Medium,34,5,0,Successful
# 180,181,87,Female,Type C,High,47,16,0,Successful
# 181,182,28,Female,Type A,Low,65,8,1,Successful
# 182,183,33,Female,Type C,High,51,15,0,Successful
# 183,184,76,Male,Type C,Low,49,9,0,Successful
# 184,185,87,Male,Type B,Low,58,5,0,Successful
# 185,186,20,Male,Type A,Medium,65,8,1,Successful
# 186,187,37,Male,Type C,High,38,5,0,Successful
# 187,188,76,Female,Type A,High,68,7,0,Death
# 188,189,53,Male,Type B,High,47,11,1,Successful
# 189,190,36,Female,Type B,Low,59,12,0,Complication
# 190,191,84,Male,Type A,High,59,2,0,Successful
# 191,192,36,Female,Type A,Low,52,9,0,Successful
# 192,193,37,Male,Type C,High,44,7,0,Successful
# 193,194,88,Female,Type B,High,55,6,0,Successful
# 194,195,69,Male,Type B,Medium,84,10,1,Successful
# 195,196,50,Female,Type B,High,39,7,0,Successful
# 196,197,57,Male,Type A,Medium,85,16,0,Death
# 197,198,56,Female,Type C,Medium,56,15,0,Successful
# 198,199,18,Female,Type A,Low,60,15,0,Successful
# 199,200,28,Male,Type A,High,43,7,0,Successful
# 200,201,74,Female,Type A,High,48,5,0,Successful
# 201,202,67,Male,Type C,High,52,10,0,Successful
# 202,203,40,Male,Type A,Medium,44,9,1,Successful
# 203,204,48,Male,Type B,High,56,6,0,Successful
# 204,205,59,Female,Type B,Low,53,4,0,Successful
# 205,206,24,Female,Type B,Low,87,9,0,Successful
# 206,207,33,Male,Type C,High,42,7,1,Successful
# 207,208,77,Male,Type A,Medium,61,13,1,Successful
# 208,209,19,Female,Type C,Low,63,13,0,Successful
# 209,210,18,Female,Type A,Low,43,15,0,Death
# 210,211,65,Female,Type B,Medium,70,3,0,Successful
# 211,212,29,Male,Type A,Low,54,12,0,Successful
# 212,213,86,Male,Type A,Medium,22,6,1,Death
# 213,214,54,Male,Type A,Low,69,3,0,Successful
# 214,215,49,Male,Type C,Medium,43,7,0,Successful
# 215,216,26,Male,Type A,Low,44,15,0,Successful
# 216,217,36,Female,Type A,High,70,8,0,Complication
# 217,218,65,Male,Type A,Low,54,17,0,Successful
# 218,219,20,Female,Type C,Low,73,12,0,Successful
# 219,220,37,Female,Type C,High,78,8,0,Successful
# 220,221,41,Male,Type C,High,50,15,0,Successful
# 221,222,71,Female,Type A,High,71,12,0,Successful
# 222,223,50,Male,Type B,High,48,5,0,Successful
# 223,224,41,Female,Type B,Medium,93,19,0,Successful
# 224,225,89,Male,Type B,Medium,49,11,0,Successful
# 225,226,53,Male,Type A,Low,75,10,1,Successful
# 226,227,55,Female,Type B,Low,72,5,1,Successful
# 227,228,42,Male,Type B,Low,64,15,0,Successful
# 228,229,35,Female,Type B,Medium,49,12,0,Successful
# 229,230,83,Male,Type A,Low,57,13,0,Successful
# 230,231,71,Male,Type B,Low,27,7,0,Successful
# 231,232,52,Male,Type B,Medium,63,14,0,Successful
# 232,233,78,Female,Type A,Low,65,14,0,Successful
# 233,234,58,Female,Type C,Medium,62,6,0,Successful
# 234,235,50,Male,Type B,Medium,15,2,1,Complication
# 235,236,85,Female,Type C,High,41,12,1,Successful
# 236,237,50,Male,Type B,High,48,2,0,Successful
# 237,238,31,Female,Type A,Medium,64,10,0,Successful
# 238,239,38,Female,Type C,Medium,64,7,0,Successful
# 239,240,65,Male,Type C,High,57,16,0,Successful
# 240,241,37,Male,Type C,Low,69,8,0,Successful
# 241,242,25,Male,Type C,Low,44,15,0,Death
# 242,243,24,Male,Type B,Low,69,7,0,Complication
# 243,244,84,Male,Type B,Medium,67,14,0,Successful
# 244,245,34,Female,Type C,High,65,20,0,Successful
# 245,246,50,Female,Type B,Low,57,4,1,Successful
# 246,247,65,Male,Type C,High,87,11,0,Successful
# 247,248,76,Male,Type C,High,67,23,0,Successful
# 248,249,39,Male,Type A,Medium,45,10,0,Successful
# 249,250,47,Female,Type C,Low,63,10,0,Successful
# 250,251,55,Male,Type B,High,71,13,1,Successful
# 251,252,68,Male,Type C,Medium,51,10,0,Death
# 252,253,71,Female,Type A,Medium,76,1,0,Successful
# 253,254,25,Female,Type B,Medium,65,15,0,Successful
# 254,255,44,Female,Type A,Low,24,0,1,Successful
# 255,256,44,Female,Type A,Low,64,7,0,Complication
# 256,257,38,Male,Type C,Medium,53,16,1,Complication
# 257,258,47,Female,Type A,Low,68,8,0,Successful
# 258,259,45,Female,Type A,Low,74,6,0,Complication
# 259,260,81,Male,Type B,High,62,14,0,Successful
# 260,261,86,Male,Type A,Medium,84,5,0,Successful
# 261,262,78,Male,Type C,Medium,57,3,0,Successful
# 262,263,65,Female,Type C,Low,69,11,0,Successful
# 263,264,36,Male,Type C,Medium,72,9,0,Successful
# 264,265,21,Female,Type A,Medium,58,3,1,Successful
# 265,266,52,Female,Type B,Medium,71,13,0,Successful
# 266,267,81,Female,Type C,Low,51,12,0,Successful
# 267,268,66,Male,Type A,Low,53,8,0,Successful
# 268,269,34,Female,Type C,Low,40,8,0,Successful
# 269,270,61,Male,Type C,High,63,12,0,Successful
# 270,271,47,Male,Type B,Medium,64,15,0,Successful
# 271,272,63,Male,Type C,High,77,8,1,Successful
# 272,273,23,Female,Type B,Low,71,13,0,Complication
# 273,274,54,Female,Type A,High,55,12,1,Successful
# 274,275,41,Female,Type C,Medium,42,14,0,Successful
# 275,276,63,Male,Type A,Medium,66,10,0,Successful
# 276,277,70,Female,Type A,Low,76,5,0,Death
# 277,278,77,Female,Type A,Low,71,7,0,Successful
# 278,279,80,Female,Type C,High,76,11,0,Complication
# 279,280,49,Female,Type B,Low,56,19,1,Successful
# 280,281,50,Female,Type C,High,53,7,0,Death
# 281,282,84,Male,Type A,Medium,48,14,0,Successful
# 282,283,35,Male,Type B,Medium,59,8,1,Death
# 283,284,42,Male,Type A,Medium,58,10,0,Successful
# 284,285,71,Male,Type B,Medium,63,17,1,Death
# 285,286,75,Female,Type C,Medium,58,13,0,Successful
# 286,287,84,Male,Type B,High,57,3,0,Successful
# 287,288,63,Female,Type C,Medium,48,7,0,Successful
# 288,289,41,Male,Type A,High,74,16,0,Successful
# 289,290,49,Male,Type B,Medium,61,10,0,Successful
# 290,291,64,Male,Type A,High,57,4,0,Successful
# 291,292,40,Female,Type B,High,48,5,0,Successful
# 292,293,83,Female,Type C,High,40,13,1,Complication
# 293,294,44,Male,Type B,Low,79,14,0,Successful
# 294,295,19,Female,Type B,High,68,10,0,Successful
# 295,296,34,Male,Type C,High,35,22,1,Complication
# 296,297,50,Male,Type C,Medium,71,14,1,Successful
# 297,298,26,Male,Type C,High,73,8,0,Successful
# 298,299,60,Female,Type B,High,61,5,1,Complication
# 299,300,65,Male,Type A,Low,83,5,0,Successful
# 300,301,56,Male,Type B,Medium,63,11,0,Successful
# 301,302,59,Male,Type B,Low,38,7,0,Death
# 302,303,43,Female,Type A,Low,65,18,0,Complication
# 303,304,67,Male,Type C,Low,63,17,0,Successful
# 304,305,42,Female,Type B,High,50,13,0,Successful
# 305,306,41,Male,Type A,Low,68,4,0,Successful
# 306,307,30,Female,Type C,Low,34,6,1,Successful
# 307,308,77,Male,Type C,Medium,74,16,0,Successful
# 308,309,24,Male,Type B,Medium,46,7,1,Successful
# 309,310,74,Female,Type C,Medium,45,15,0,Successful
# 310,311,53,Female,Type C,Medium,58,12,1,Successful
# 311,312,62,Male,Type A,Low,66,10,0,Successful
# 312,313,37,Female,Type A,Medium,62,6,1,Complication
# 313,314,82,Male,Type C,High,48,9,0,Complication
# 314,315,25,Male,Type A,Low,52,10,0,Successful
# 315,316,33,Male,Type C,Medium,43,15,0,Successful
# 316,317,31,Female,Type B,Low,56,5,0,Successful
# 317,318,32,Male,Type A,Medium,76,8,0,Successful
# 318,319,83,Female,Type C,Low,59,10,0,Successful
# 319,320,49,Male,Type C,Medium,72,13,0,Successful
# 320,321,80,Female,Type A,High,81,5,0,Successful
# 321,322,68,Female,Type A,Medium,51,3,0,Successful
# 322,323,42,Male,Type B,Low,57,13,0,Successful
# 323,324,75,Female,Type C,Low,92,2,0,Successful
# 324,325,80,Male,Type B,High,81,16,0,Successful
# 325,326,79,Male,Type B,Low,34,9,0,Successful
# 326,327,39,Male,Type B,High,65,2,0,Successful
# 327,328,75,Male,Type A,Low,60,7,0,Successful
# 328,329,75,Male,Type B,Low,72,11,1,Successful
# 329,330,66,Female,Type A,High,48,7,0,Death
# 330,331,69,Male,Type A,Low,47,10,1,Successful
# 331,332,59,Female,Type B,Low,49,13,0,Successful
# 332,333,87,Female,Type B,High,51,8,0,Complication
# 333,334,32,Male,Type C,Medium,72,5,0,Successful
# 334,335,71,Female,Type B,High,42,8,1,Successful
# 335,336,77,Male,Type C,Low,50,17,0,Successful
# 336,337,25,Female,Type B,Medium,33,18,0,Successful
# 337,338,70,Female,Type B,Medium,75,0,0,Successful
# 338,339,77,Female,Type B,Medium,79,15,0,Successful
# 339,340,22,Male,Type B,High,55,11,0,Complication
# 340,341,85,Female,Type C,Medium,55,14,0,Successful
# 341,342,23,Male,Type C,Medium,66,7,0,Complication
# 342,343,64,Female,Type B,Medium,82,1,1,Complication
# 343,344,72,Female,Type B,Low,66,12,1,Death
# 344,345,57,Female,Type C,High,49,5,0,Successful
# 345,346,69,Female,Type A,High,35,3,0,Successful
# 346,347,33,Male,Type A,Low,43,3,0,Successful
# 347,348,30,Male,Type A,Medium,61,13,0,Successful
# 348,349,47,Female,Type C,Low,50,10,0,Complication
# 349,350,36,Female,Type C,Low,62,13,0,Successful
# 350,351,34,Male,Type A,Medium,51,13,1,Successful
# 351,352,80,Male,Type A,Medium,44,7,1,Complication
# 352,353,36,Male,Type B,High,42,9,0,Successful
# 353,354,75,Male,Type C,Medium,83,7,0,Successful
# 354,355,72,Female,Type C,Low,73,8,1,Successful
# 355,356,79,Female,Type A,Low,85,5,1,Successful
# 356,357,40,Male,Type A,Medium,68,11,0,Successful
# 357,358,26,Male,Type C,High,53,15,0,Successful
# 358,359,29,Male,Type B,Low,79,5,0,Complication
# 359,360,18,Male,Type A,Medium,59,16,0,Successful
# 360,361,75,Male,Type C,High,63,10,0,Successful
# 361,362,18,Male,Type C,High,59,11,1,Successful
# 362,363,51,Female,Type B,Low,15,1,0,Successful
# 363,364,65,Female,Type B,Low,84,0,0,Successful
# 364,365,18,Female,Type A,High,67,10,0,Successful
# 365,366,33,Male,Type A,High,64,13,0,Successful
# 366,367,78,Male,Type A,High,59,6,1,Successful
# 367,368,81,Male,Type C,Medium,62,18,0,Successful
# 368,369,80,Female,Type A,Low,51,13,1,Successful
# 369,370,86,Male,Type C,High,69,5,0,Successful
# 370,371,39,Male,Type A,Low,40,10,0,Successful
# 371,372,84,Female,Type B,Low,62,22,0,Successful
# 372,373,43,Male,Type B,Low,68,3,0,Complication
# 373,374,33,Female,Type C,High,57,12,0,Successful
# 374,375,68,Female,Type B,Medium,65,8,1,Successful
# 375,376,74,Male,Type C,High,45,13,0,Death
# 376,377,46,Female,Type C,Low,45,16,0,Successful
# 377,378,86,Male,Type B,High,63,8,0,Death
# 378,379,64,Female,Type C,High,70,15,0,Successful
# 379,380,79,Male,Type B,Low,31,21,0,Complication
# 380,381,86,Female,Type A,Low,67,10,1,Successful
# 381,382,33,Male,Type A,High,51,13,0,Successful
# 382,383,65,Female,Type B,High,57,7,1,Death
# 383,384,56,Female,Type B,High,39,10,0,Death
# 384,385,50,Female,Type B,High,47,9,0,Successful
# 385,386,40,Male,Type B,Medium,74,13,0,Death
# 386,387,27,Male,Type A,High,60,16,0,Successful
# 387,388,86,Female,Type C,Medium,54,9,0,Successful
# 388,389,51,Male,Type C,Low,58,17,0,Successful
# 389,390,69,Female,Type A,Medium,67,17,0,Successful
# 390,391,27,Male,Type C,Low,66,14,0,Successful
# 391,392,36,Female,Type A,Medium,58,7,0,Successful
# 392,393,75,Male,Type C,Low,76,6,0,Successful
# 393,394,18,Female,Type B,High,74,5,0,Successful
# 394,395,86,Female,Type B,Medium,66,14,1,Successful
# 395,396,21,Female,Type B,Medium,60,3,0,Successful
# 396,397,33,Female,Type A,Low,69,13,0,Successful
# 397,398,41,Male,Type A,Low,64,4,1,Successful
# 398,399,19,Female,Type C,Medium,75,14,0,Successful
# 399,400,49,Male,Type C,Low,73,10,0,Successful
# 400,401,41,Male,Type C,High,44,16,1,Successful
# 401,402,29,Female,Type A,Medium,43,15,0,Successful
# 402,403,67,Male,Type C,High,49,17,0,Successful
# 403,404,52,Male,Type B,Medium,74,17,0,Successful
# 404,405,50,Male,Type C,High,36,10,0,Successful
# 405,406,50,Female,Type B,Medium,65,4,0,Complication
# 406,407,78,Male,Type A,Low,65,4,0,Successful
# 407,408,68,Male,Type B,Medium,77,0,0,Successful
# 408,409,60,Female,Type B,High,62,4,0,Successful
# 409,410,29,Female,Type B,Medium,39,10,0,Successful
# 410,411,84,Male,Type A,High,45,7,0,Successful
# 411,412,82,Female,Type A,High,42,9,0,Successful
# 412,413,50,Male,Type A,High,51,12,0,Successful
# 413,414,57,Male,Type A,Low,57,8,0,Death
# 414,415,60,Male,Type C,Medium,42,4,0,Successful
# 415,416,61,Female,Type A,High,82,9,0,Successful
# 416,417,46,Male,Type B,Low,40,5,0,Successful
# 417,418,30,Female,Type A,High,80,8,0,Successful
# 418,419,29,Female,Type C,Medium,77,16,0,Successful
# 419,420,63,Male,Type C,Low,73,8,1,Complication
# 420,421,19,Female,Type C,High,49,18,0,Successful
# 421,422,52,Female,Type B,High,65,17,0,Successful
# 422,423,25,Female,Type A,High,40,7,0,Successful
# 423,424,43,Female,Type A,Medium,73,4,0,Successful
# 424,425,51,Female,Type A,Low,58,9,0,Successful
# 425,426,24,Male,Type B,Low,53,15,0,Successful
# 426,427,85,Female,Type B,Low,41,7,0,Successful
# 427,428,75,Male,Type C,High,22,14,0,Successful
# 428,429,46,Male,Type C,Low,44,16,1,Successful
# 429,430,53,Male,Type A,High,76,6,1,Successful
# 430,431,38,Male,Type B,Medium,53,6,0,Successful
# 431,432,53,Male,Type B,Low,57,13,0,Successful
# 432,433,27,Male,Type A,High,69,10,1,Successful
# 433,434,41,Female,Type A,Low,87,6,0,Complication
# 434,435,81,Female,Type C,Low,79,8,0,Successful
# 435,436,66,Female,Type C,Medium,45,9,0,Successful
# 436,437,53,Male,Type C,Low,30,2,0,Death
# 437,438,41,Female,Type A,Medium,95,13,1,Successful
# 438,439,40,Female,Type A,Low,94,7,0,Successful
# 439,440,79,Female,Type C,Low,62,-3,0,Successful
# 440,441,54,Male,Type C,Low,40,9,0,Successful
# 441,442,29,Female,Type B,Low,74,6,1,Death
# 442,443,72,Male,Type B,Low,58,18,0,Successful
# 443,444,30,Female,Type C,Low,58,7,0,Successful
# 444,445,40,Male,Type C,Medium,73,4,1,Death
# 445,446,47,Male,Type B,Medium,65,12,0,Successful
# 446,447,34,Male,Type C,High,42,6,0,Successful
# 447,448,79,Female,Type B,Low,55,6,0,Successful
# 448,449,30,Female,Type B,Medium,69,12,0,Successful
# 449,450,76,Male,Type B,Low,67,4,0,Successful
# 450,451,36,Female,Type A,Low,63,2,0,Successful
# 451,452,66,Male,Type A,Medium,74,18,0,Complication
# 452,453,29,Male,Type C,Low,54,12,0,Successful
# 453,454,78,Female,Type B,Medium,62,8,0,Successful
# 454,455,36,Female,Type A,Medium,9,9,0,Successful
# 455,456,26,Female,Type C,High,53,12,1,Successful
# 456,457,88,Male,Type C,High,71,14,0,Successful
# 457,458,45,Male,Type C,High,54,6,0,Death
# 458,459,69,Female,Type C,High,53,11,0,Successful
# 459,460,33,Male,Type C,Low,44,7,0,Successful
# 460,461,86,Female,Type B,Low,75,9,0,Successful
# 461,462,29,Male,Type C,High,68,10,0,Successful
# 462,463,42,Female,Type B,Medium,72,9,0,Successful
# 463,464,69,Female,Type A,Medium,34,13,0,Successful
# 464,465,70,Male,Type C,Medium,57,12,0,Successful
# 465,466,40,Female,Type A,Medium,55,2,0,Successful
# 466,467,33,Female,Type B,Low,55,3,0,Successful
# 467,468,74,Male,Type B,Medium,50,8,0,Complication
# 468,469,56,Female,Type A,Medium,54,19,0,Complication
# 469,470,70,Male,Type C,High,72,5,0,Complication
# 470,471,59,Female,Type C,Medium,31,8,1,Successful
# 471,472,75,Male,Type A,Low,86,7,1,Complication
# 472,473,56,Female,Type A,Medium,67,7,0,Successful
# 473,474,31,Female,Type A,Medium,59,10,0,Successful
# 474,475,22,Female,Type C,Low,73,17,0,Successful
# 475,476,52,Female,Type C,High,38,12,0,Successful
# 476,477,35,Male,Type C,Low,50,5,0,Successful
# 477,478,26,Male,Type A,High,58,23,0,Successful
# 478,479,75,Male,Type C,Medium,80,10,0,Successful
# 479,480,34,Male,Type B,High,59,7,0,Successful
# 480,481,24,Male,Type A,High,66,17,1,Successful
# 481,482,63,Male,Type C,High,51,7,0,Successful
# 482,483,30,Male,Type A,Medium,67,18,0,Complication
# 483,484,57,Female,Type B,High,85,5,0,Successful
# 484,485,59,Female,Type B,High,74,17,0,Successful
# 485,486,26,Female,Type A,Medium,58,11,1,Successful
# 486,487,67,Female,Type A,Low,70,16,0,Successful
# 487,488,44,Male,Type B,Low,68,19,0,Successful
# 488,489,83,Male,Type A,Low,67,4,0,Successful
# 489,490,22,Male,Type B,Medium,76,16,0,Successful
# 490,491,46,Female,Type B,Medium,76,2,0,Successful
# 491,492,54,Male,Type C,Low,58,4,0,Successful
# 492,493,55,Female,Type A,High,69,5,0,Successful
# 493,494,25,Male,Type A,Low,54,12,0,Death
# 494,495,82,Male,Type C,Medium,46,10,0,Successful
# 495,496,34,Male,Type B,High,55,9,0,Successful
# 496,497,88,Male,Type A,High,58,10,0,Death
# 497,498,62,Female,Type C,Medium,35,12,0,Successful
# 498,499,21,Female,Type C,High,72,13,0,Successful
# 499,500,53,Male,Type A,Low,18,15,0,Successful
# 500,501,87,Female,Type C,Medium,100,19,0,Successful
# 501,502,48,Male,Type B,Medium,82,9,0,Successful
# 502,503,36,Male,Type C,Medium,56,7,0,Successful
# 503,504,78,Male,Type B,Medium,60,13,0,Complication
# 504,505,71,Male,Type B,High,64,4,0,Complication
# 505,506,56,Female,Type A,Medium,51,6,0,Successful
# 506,507,36,Male,Type C,Medium,62,14,1,Successful
# 507,508,56,Male,Type B,High,57,9,0,Complication
# 508,509,84,Female,Type B,Medium,58,3,0,Successful
# 509,510,62,Male,Type C,High,62,2,1,Successful
# 510,511,30,Female,Type B,High,40,10,1,Successful
# 511,512,75,Male,Type C,Medium,60,15,0,Successful
# 512,513,37,Male,Type A,Low,62,15,1,Successful
# 513,514,89,Male,Type B,Medium,61,10,1,Successful
# 514,515,78,Male,Type B,Low,56,20,0,Successful
# 515,516,56,Male,Type C,High,77,9,0,Complication
# 516,517,18,Male,Type C,Low,54,9,0,Successful
# 517,518,20,Female,Type C,Medium,63,-2,0,Successful
# 518,519,79,Male,Type C,Medium,79,7,0,Successful
# 519,520,80,Female,Type B,Low,58,14,0,Successful
# 520,521,42,Female,Type A,Medium,63,17,0,Successful
# 521,522,73,Male,Type A,Low,58,5,0,Successful
# 522,523,50,Female,Type A,High,78,12,1,Successful
# 523,524,55,Male,Type A,Low,56,15,0,Successful
# 524,525,23,Female,Type C,Low,79,10,0,Successful
# 525,526,75,Male,Type B,Low,58,-1,0,Death
# 526,527,61,Female,Type B,Low,47,11,0,Successful
# 527,528,62,Female,Type B,High,70,13,0,Successful
# 528,529,49,Male,Type C,High,55,5,0,Successful
# 529,530,62,Female,Type B,High,69,8,0,Successful
# 530,531,78,Male,Type C,Low,19,4,1,Successful
# 531,532,64,Male,Type B,High,60,-2,0,Successful
# 532,533,38,Male,Type A,Medium,53,15,1,Successful
# 533,534,53,Male,Type C,High,44,9,0,Successful
# 534,535,36,Male,Type B,Low,51,17,0,Successful
# 535,536,37,Female,Type A,Medium,51,14,0,Successful
# 536,537,74,Female,Type A,Low,59,8,1,Successful
# 537,538,35,Female,Type A,Medium,39,9,0,Successful
# 538,539,64,Male,Type C,Low,64,12,1,Successful
# 539,540,66,Female,Type C,Low,80,14,1,Successful
# 540,541,31,Female,Type B,Medium,64,11,0,Successful
# 541,542,32,Female,Type A,High,72,15,0,Successful
# 542,543,48,Female,Type B,Medium,76,8,0,Successful
# 543,544,18,Female,Type B,Medium,78,5,0,Successful
# 544,545,71,Male,Type A,Medium,88,9,0,Successful
# 545,546,20,Male,Type B,Medium,52,11,0,Complication
# 546,547,33,Female,Type C,Medium,49,3,0,Successful
# 547,548,74,Male,Type B,Low,71,3,0,Successful
# 548,549,29,Male,Type A,Low,70,12,0,Successful
# 549,550,33,Female,Type C,High,71,7,0,Successful
# 550,551,89,Female,Type C,High,88,9,1,Complication
# 551,552,41,Male,Type B,Medium,60,8,0,Successful
# 552,553,45,Female,Type B,High,66,17,0,Successful
# 553,554,25,Male,Type C,High,45,16,0,Successful
# 554,555,53,Male,Type B,Medium,92,3,1,Successful
# 555,556,25,Female,Type A,Low,54,7,1,Successful
# 556,557,75,Male,Type B,Low,55,14,0,Successful
# 557,558,77,Male,Type B,High,54,13,0,Successful
# 558,559,67,Male,Type C,Low,50,9,0,Complication
# 559,560,45,Female,Type B,Low,49,4,0,Death
# 560,561,58,Female,Type B,High,52,6,0,Successful
# 561,562,81,Female,Type B,Medium,39,7,0,Successful
# 562,563,44,Female,Type A,High,48,11,0,Complication
# 563,564,80,Male,Type B,High,89,18,0,Successful
# 564,565,34,Female,Type A,High,71,6,0,Successful
# 565,566,50,Female,Type A,Medium,73,4,0,Complication
# 566,567,46,Female,Type A,Medium,77,9,0,Successful
# 567,568,30,Female,Type A,Medium,87,15,0,Complication
# 568,569,63,Male,Type C,Medium,33,2,0,Successful
# 569,570,52,Male,Type A,High,41,17,0,Successful
# 570,571,23,Male,Type B,Low,47,9,0,Successful
# 571,572,86,Female,Type A,High,52,6,0,Successful
# 572,573,64,Female,Type B,Medium,55,1,1,Successful
# 573,574,42,Male,Type A,Low,53,13,1,Successful
# 574,575,83,Female,Type C,High,63,9,0,Successful
# 575,576,27,Female,Type A,Low,60,10,0,Successful
# 576,577,73,Male,Type A,Medium,49,5,0,Successful
# 577,578,47,Male,Type C,Low,27,8,1,Successful
# 578,579,22,Female,Type A,Low,45,7,0,Successful
# 579,580,50,Female,Type B,Medium,51,9,0,Successful
# 580,581,82,Female,Type A,Low,56,6,0,Successful
# 581,582,35,Male,Type A,High,43,2,1,Successful
# 582,583,66,Male,Type A,Low,52,23,0,Successful
# 583,584,28,Male,Type C,High,43,3,0,Complication
# 584,585,43,Male,Type A,Low,58,10,0,Successful
# 585,586,80,Female,Type A,Low,43,1,0,Successful
# 586,587,76,Male,Type B,Medium,47,0,0,Successful
# 587,588,44,Male,Type A,Medium,40,10,0,Successful
# 588,589,66,Female,Type A,High,57,10,0,Successful
# 589,590,50,Female,Type A,Medium,47,16,0,Successful
# 590,591,18,Female,Type A,Medium,73,11,0,Successful
# 591,592,38,Male,Type B,Medium,66,9,0,Death
# 592,593,72,Female,Type B,Medium,58,5,0,Complication
# 593,594,23,Female,Type C,Medium,48,17,0,Successful
# 594,595,86,Male,Type A,High,65,14,0,Successful
# 595,596,22,Male,Type C,High,70,3,0,Successful
# 596,597,20,Female,Type C,Medium,62,10,0,Successful
# 597,598,70,Male,Type A,Medium,84,10,0,Successful
# 598,599,40,Female,Type B,High,66,8,0,Successful
# 599,600,70,Female,Type B,Low,73,13,1,Successful
# 600,601,54,Male,Type A,High,62,14,0,Successful
# 601,602,34,Female,Type A,Low,70,9,0,Complication
# 602,603,18,Male,Type B,Medium,48,8,0,Complication
# 603,604,68,Male,Type A,Medium,53,17,0,Successful
# 604,605,62,Male,Type A,High,65,14,0,Successful
# 605,606,21,Female,Type A,Medium,65,10,0,Successful
# 606,607,79,Male,Type B,Low,67,1,0,Successful
# 607,608,82,Male,Type C,Low,76,11,0,Complication
# 608,609,49,Female,Type C,High,38,13,0,Successful
# 609,610,51,Female,Type A,Low,45,-3,0,Successful
# 610,611,89,Female,Type B,High,63,11,0,Successful
# 611,612,56,Female,Type A,High,49,7,0,Complication
# 612,613,43,Male,Type B,Low,110,8,0,Successful
# 613,614,51,Male,Type A,Low,67,5,0,Successful
# 614,615,71,Male,Type B,Low,58,9,0,Complication
# 615,616,20,Female,Type B,Low,52,16,0,Successful
# 616,617,67,Female,Type C,Low,52,7,1,Successful
# 617,618,29,Male,Type A,Low,60,14,1,Successful
# 618,619,82,Female,Type C,Low,61,5,1,Complication
# 619,620,71,Female,Type C,Medium,53,13,1,Successful
# 620,621,22,Male,Type B,High,55,10,0,Successful
# 621,622,74,Male,Type A,High,80,11,0,Successful
# 622,623,34,Female,Type B,Low,80,10,0,Successful
# 623,624,64,Female,Type B,High,63,13,0,Successful
# 624,625,40,Female,Type B,Low,39,-2,0,Successful
# 625,626,31,Male,Type A,Medium,68,2,0,Successful
# 626,627,83,Male,Type A,High,83,12,1,Successful
# 627,628,68,Male,Type B,High,80,0,0,Death
# 628,629,55,Male,Type A,Medium,71,7,1,Successful
# 629,630,81,Male,Type B,Medium,81,9,0,Successful
# 630,631,55,Female,Type A,Medium,60,5,0,Successful
# 631,632,67,Female,Type A,High,69,6,0,Successful
# 632,633,47,Female,Type C,High,49,11,0,Successful
# 633,634,68,Male,Type B,Medium,64,15,0,Successful
# 634,635,80,Male,Type C,Medium,79,5,0,Successful
# 635,636,69,Male,Type C,Medium,51,7,0,Death
# 636,637,55,Female,Type B,Medium,47,6,0,Successful
# 637,638,47,Male,Type B,Medium,61,-2,0,Successful
# 638,639,68,Male,Type A,Low,56,10,1,Successful
# 639,640,22,Female,Type B,Medium,69,14,0,Successful
# 640,641,46,Male,Type C,Low,53,15,0,Successful
# 641,642,21,Female,Type C,High,85,5,0,Successful
# 642,643,27,Male,Type B,High,40,3,0,Death
# 643,644,73,Male,Type C,Low,78,10,0,Successful
# 644,645,34,Female,Type A,Medium,48,14,0,Successful
# 645,646,34,Female,Type C,High,33,10,1,Complication
# 646,647,86,Female,Type A,Medium,63,11,0,Successful
# 647,648,51,Female,Type C,Medium,56,15,1,Successful
# 648,649,23,Female,Type A,Low,43,6,0,Successful
# 649,650,70,Female,Type A,High,34,8,0,Death
# 650,651,83,Male,Type B,High,59,18,0,Successful
# 651,652,60,Male,Type A,Low,74,9,0,Successful
# 652,653,40,Female,Type B,Medium,68,3,0,Successful
# 653,654,72,Male,Type C,Medium,60,6,0,Successful
# 654,655,33,Female,Type C,High,67,5,0,Successful
# 655,656,25,Male,Type C,Low,59,11,0,Successful
# 656,657,21,Female,Type A,Low,38,5,0,Successful
# 657,658,21,Male,Type C,Medium,38,11,0,Successful
# 658,659,73,Male,Type C,Medium,56,6,0,Successful
# 659,660,42,Male,Type B,Low,57,0,0,Successful
# 660,661,84,Male,Type B,High,72,11,0,Successful
# 661,662,84,Male,Type C,Medium,71,10,0,Successful
# 662,663,44,Female,Type C,Low,69,12,0,Successful
# 663,664,49,Female,Type A,Low,55,6,1,Successful
# 664,665,67,Female,Type A,Low,39,6,0,Successful
# 665,666,78,Male,Type C,High,66,12,0,Complication
# 666,667,68,Female,Type B,Medium,67,17,0,Successful
# 667,668,36,Male,Type C,Medium,24,10,0,Successful
# 668,669,38,Male,Type A,Medium,47,12,1,Complication
# 669,670,22,Male,Type B,High,49,8,0,Successful
# 670,671,59,Female,Type B,Medium,61,2,0,Successful
# 671,672,78,Male,Type A,Medium,47,14,0,Successful
# 672,673,39,Female,Type C,Medium,59,14,0,Successful
# 673,674,38,Female,Type C,Medium,56,13,0,Successful
# 674,675,87,Male,Type C,High,57,9,1,Successful
# 675,676,18,Male,Type A,Low,49,12,1,Complication
# 676,677,22,Female,Type B,Low,50,14,0,Complication
# 677,678,29,Female,Type A,Medium,43,18,0,Successful
# 678,679,63,Female,Type C,Medium,65,14,0,Complication
# 679,680,51,Female,Type A,Medium,68,10,0,Successful
# 680,681,66,Female,Type B,High,48,3,0,Successful
# 681,682,62,Female,Type A,Medium,82,10,0,Successful
# 682,683,44,Male,Type C,High,55,11,0,Successful
# 683,684,43,Female,Type B,Medium,82,13,0,Successful
# 684,685,64,Female,Type A,Medium,50,16,0,Successful
# 685,686,73,Female,Type A,Low,29,9,1,Successful
# 686,687,80,Female,Type B,Medium,66,20,0,Successful
# 687,688,65,Male,Type B,High,63,1,1,Complication
# 688,689,78,Male,Type C,Low,60,12,0,Successful
# 689,690,43,Female,Type B,High,50,6,0,Successful
# 690,691,53,Female,Type C,Low,59,0,0,Death
# 691,692,18,Female,Type A,High,52,8,0,Successful
# 692,693,25,Male,Type C,Low,55,2,0,Successful
# 693,694,69,Male,Type A,High,72,9,1,Successful
# 694,695,64,Male,Type B,High,62,10,0,Death
# 695,696,73,Male,Type A,Medium,69,15,0,Successful
# 696,697,31,Male,Type B,Low,56,2,0,Successful
# 697,698,45,Male,Type A,Low,54,14,1,Successful
# 698,699,19,Female,Type A,Medium,42,10,0,Successful
# 699,700,43,Male,Type A,High,54,15,0,Successful
# 700,701,31,Male,Type A,High,10,7,1,Successful
# 701,702,76,Female,Type C,Low,51,3,0,Successful
# 702,703,73,Male,Type A,High,58,3,0,Successful
# 703,704,24,Female,Type C,Low,68,3,0,Successful
# 704,705,20,Male,Type B,Low,55,12,0,Successful
# 705,706,40,Female,Type B,High,65,17,1,Successful
# 706,707,35,Female,Type C,High,27,7,0,Successful
# 707,708,55,Female,Type B,High,59,13,0,Successful
# 708,709,32,Female,Type B,Medium,34,2,1,Successful
# 709,710,81,Female,Type A,Low,41,10,0,Successful
# 710,711,45,Male,Type A,High,57,13,1,Successful
# 711,712,56,Male,Type A,Medium,79,2,0,Successful
# 712,713,74,Female,Type C,High,65,8,0,Complication
# 713,714,34,Female,Type C,Low,60,13,0,Successful
# 714,715,61,Female,Type B,Medium,59,-4,1,Successful
# 715,716,42,Male,Type A,Low,49,16,0,Successful
# 716,717,34,Female,Type C,High,51,11,1,Death
# 717,718,30,Female,Type C,High,66,13,0,Complication
# 718,719,42,Female,Type A,High,39,7,0,Successful
# 719,720,85,Female,Type C,Medium,68,1,0,Successful
# 720,721,27,Male,Type A,Medium,54,12,0,Successful
# 721,722,84,Female,Type B,Medium,72,9,0,Successful
# 722,723,35,Female,Type B,Medium,74,10,1,Successful
# 723,724,51,Male,Type B,High,34,15,0,Successful
# 724,725,25,Female,Type A,High,51,13,0,Complication
# 725,726,57,Female,Type C,High,47,19,1,Successful
# 726,727,59,Male,Type B,Medium,32,10,0,Death
# 727,728,58,Male,Type B,Medium,44,6,1,Successful
# 728,729,23,Male,Type B,High,96,9,0,Successful
# 729,730,69,Female,Type C,High,69,12,0,Successful
# 730,731,43,Female,Type C,Medium,88,15,0,Successful
# 731,732,81,Male,Type A,Low,72,2,0,Successful
# 732,733,76,Male,Type B,High,48,10,0,Successful
# 733,734,73,Male,Type C,High,54,18,1,Successful
# 734,735,76,Female,Type A,High,68,8,1,Successful
# 735,736,87,Female,Type B,Medium,66,14,0,Successful
# 736,737,50,Male,Type C,High,51,12,1,Successful
# 737,738,70,Female,Type C,High,37,14,0,Death
# 738,739,39,Male,Type A,High,109,5,1,Successful
# 739,740,38,Female,Type B,High,57,5,0,Death
# 740,741,87,Female,Type B,High,55,10,0,Successful
# 741,742,87,Female,Type C,Low,61,2,0,Successful
# 742,743,21,Female,Type B,Low,56,8,0,Successful
# 743,744,79,Male,Type A,High,61,11,0,Successful
# 744,745,79,Female,Type C,High,79,18,0,Successful
# 745,746,41,Female,Type C,High,58,12,0,Successful
# 746,747,72,Male,Type A,High,42,13,0,Successful
# 747,748,26,Female,Type C,Medium,57,15,1,Successful
# 748,749,20,Male,Type B,Medium,53,5,0,Successful
# 749,750,48,Male,Type B,Medium,81,9,0,Successful
# 750,751,57,Female,Type C,Low,77,22,0,Successful
# 751,752,53,Female,Type A,High,61,9,0,Successful
# 752,753,41,Male,Type A,Medium,40,15,0,Complication
# 753,754,23,Male,Type B,High,41,14,0,Successful
# 754,755,83,Male,Type A,High,60,2,0,Successful
# 755,756,21,Female,Type C,Low,65,11,0,Complication
# 756,757,23,Male,Type C,Low,54,10,0,Successful
# 757,758,68,Male,Type B,Medium,52,11,1,Successful
# 758,759,79,Male,Type B,Medium,51,6,0,Successful
# 759,760,74,Female,Type B,Low,59,4,0,Successful
# 760,761,83,Male,Type A,Low,24,7,0,Successful
# 761,762,25,Female,Type C,High,43,9,0,Successful
# 762,763,43,Female,Type C,High,50,15,0,Successful
# 763,764,68,Male,Type C,Medium,78,19,0,Successful
# 764,765,62,Female,Type B,Medium,47,16,0,Successful
# 765,766,61,Male,Type C,Low,62,14,0,Successful
# 766,767,22,Female,Type A,Medium,63,4,0,Complication
# 767,768,87,Female,Type A,High,79,7,0,Successful
# 768,769,43,Male,Type C,Low,78,11,0,Successful
# 769,770,85,Male,Type B,High,59,6,0,Successful
# 770,771,36,Male,Type C,Low,52,12,0,Successful
# 771,772,37,Female,Type A,Low,50,13,0,Successful
# 772,773,29,Female,Type A,High,56,12,0,Successful
# 773,774,64,Male,Type A,Medium,53,15,0,Successful
# 774,775,18,Male,Type C,Medium,68,5,0,Successful
# 775,776,31,Female,Type A,Medium,66,14,0,Successful
# 776,777,81,Female,Type B,Medium,68,6,0,Successful
# 777,778,55,Female,Type C,High,78,5,0,Successful
# 778,779,54,Male,Type C,Low,87,12,1,Successful
# 779,780,28,Female,Type A,High,61,16,0,Successful
# 780,781,20,Male,Type A,Medium,76,12,0,Successful
# 781,782,50,Female,Type B,Medium,54,10,0,Death
# 782,783,23,Female,Type C,High,77,11,0,Successful
# 783,784,67,Male,Type A,Low,75,10,0,Successful
# 784,785,27,Male,Type B,High,75,4,0,Successful
# 785,786,22,Male,Type A,High,61,3,0,Complication
# 786,787,40,Female,Type C,High,49,9,0,Successful
# 787,788,27,Female,Type A,Low,39,10,0,Successful
# 788,789,61,Female,Type C,High,59,10,1,Successful
# 789,790,19,Male,Type A,High,82,13,1,Death
# 790,791,30,Female,Type C,Medium,55,8,0,Successful
# 791,792,57,Male,Type B,High,71,12,0,Successful
# 792,793,19,Male,Type C,Medium,72,9,0,Successful
# 793,794,82,Male,Type B,Medium,55,19,0,Successful
# 794,795,80,Female,Type C,Medium,79,10,0,Successful
# 795,796,34,Female,Type B,Low,16,21,0,Successful
# 796,797,26,Male,Type A,Medium,41,11,0,Successful
# 797,798,32,Female,Type C,High,46,8,1,Successful
# 798,799,41,Male,Type A,High,47,5,1,Successful
# 799,800,55,Male,Type B,Medium,65,2,0,Complication
# 800,801,52,Female,Type C,Medium,64,5,1,Complication
# 801,802,66,Male,Type C,High,65,5,0,Successful
# 802,803,86,Male,Type A,Medium,68,11,0,Successful
# 803,804,79,Female,Type C,Low,45,7,0,Successful
# 804,805,77,Male,Type C,Medium,41,10,0,Successful
# 805,806,67,Male,Type A,Low,65,16,0,Successful
# 806,807,26,Male,Type C,Low,50,9,1,Successful
# 807,808,51,Male,Type A,Low,36,20,0,Successful
# 808,809,52,Male,Type A,Medium,74,4,0,Successful
# 809,810,18,Male,Type A,Low,80,9,0,Successful
# 810,811,57,Male,Type A,Low,83,7,0,Successful
# 811,812,81,Female,Type A,Medium,62,14,1,Successful
# 812,813,39,Female,Type B,Low,69,-1,0,Successful
# 813,814,77,Male,Type B,Medium,80,2,0,Successful
# 814,815,81,Male,Type A,High,50,9,0,Successful
# 815,816,89,Female,Type B,Low,76,17,0,Death
# 816,817,28,Female,Type B,Medium,64,11,0,Successful
# 817,818,31,Female,Type C,High,73,3,0,Successful
# 818,819,77,Female,Type A,Low,62,4,1,Successful
# 819,820,47,Female,Type B,Low,79,18,1,Successful
# 820,821,52,Male,Type C,Medium,63,6,1,Successful
# 821,822,54,Female,Type C,High,37,5,0,Successful
# 822,823,22,Female,Type A,Medium,81,17,1,Complication
# 823,824,43,Female,Type A,Low,45,15,0,Successful
# 824,825,79,Male,Type C,Low,78,16,1,Successful
# 825,826,21,Male,Type A,Low,58,5,1,Successful
# 826,827,59,Male,Type A,Low,77,2,1,Successful
# 827,828,35,Male,Type C,High,77,10,1,Successful
# 828,829,57,Male,Type C,High,66,11,0,Successful
# 829,830,89,Male,Type A,Medium,67,11,0,Successful
# 830,831,56,Female,Type B,Medium,66,17,0,Successful
# 831,832,31,Male,Type A,Medium,29,1,0,Successful
# 832,833,49,Male,Type B,Low,61,14,0,Successful
# 833,834,68,Female,Type C,Medium,43,4,0,Complication
# 834,835,55,Male,Type B,High,62,14,0,Successful
# 835,836,40,Female,Type C,Medium,42,7,0,Successful
# 836,837,80,Female,Type A,Medium,42,5,1,Successful
# 837,838,32,Male,Type A,High,84,6,0,Successful
# 838,839,42,Female,Type C,High,76,2,0,Successful
# 839,840,34,Female,Type C,Low,59,10,0,Successful
# 840,841,83,Female,Type C,High,62,6,1,Successful
# 841,842,70,Female,Type A,High,56,13,0,Successful
# 842,843,68,Male,Type A,Medium,68,13,0,Successful
# 843,844,56,Female,Type B,High,49,18,1,Successful
# 844,845,68,Male,Type C,Low,74,11,0,Successful
# 845,846,87,Female,Type B,Medium,56,12,0,Successful
# 846,847,23,Female,Type A,Low,53,17,0,Death
# 847,848,84,Female,Type B,High,60,6,0,Successful
# 848,849,24,Male,Type B,Low,51,2,0,Successful
# 849,850,68,Male,Type A,Low,64,11,0,Successful
# 850,851,89,Male,Type A,High,51,2,0,Successful
# 851,852,59,Female,Type C,High,67,22,0,Successful
# 852,853,81,Female,Type B,Medium,78,17,0,Successful
# 853,854,32,Female,Type A,Medium,49,20,0,Successful
# 854,855,46,Female,Type A,Medium,58,10,1,Death
# 855,856,50,Male,Type B,High,66,12,0,Successful
# 856,857,44,Female,Type A,Low,53,7,1,Successful
# 857,858,53,Male,Type C,Low,66,14,0,Successful
# 858,859,46,Female,Type C,Medium,68,3,0,Successful
# 859,860,55,Male,Type B,Medium,76,-2,0,Successful
# 860,861,74,Male,Type C,High,50,6,0,Complication
# 861,862,44,Female,Type A,Low,45,2,0,Death
# 862,863,72,Female,Type A,Medium,55,17,0,Successful
# 863,864,50,Male,Type A,High,45,19,0,Death
# 864,865,85,Female,Type A,Medium,68,2,0,Successful
# 865,866,83,Female,Type B,High,42,16,1,Successful
# 866,867,27,Male,Type C,Low,94,14,1,Successful
# 867,868,22,Male,Type C,High,79,2,0,Successful
# 868,869,55,Male,Type A,Medium,60,8,0,Successful
# 869,870,30,Male,Type B,Medium,73,7,0,Successful
# 870,871,48,Female,Type A,Low,35,13,0,Successful
# 871,872,64,Male,Type A,Low,97,3,0,Successful
# 872,873,69,Male,Type B,Medium,51,9,1,Death
# 873,874,73,Male,Type B,Medium,58,6,1,Successful
# 874,875,32,Female,Type A,Medium,32,12,0,Successful
# 875,876,46,Male,Type C,Low,67,8,0,Successful
# 876,877,25,Female,Type A,Medium,43,7,0,Successful
# 877,878,22,Male,Type C,Low,61,8,0,Successful
# 878,879,46,Male,Type C,Medium,51,20,0,Successful
# 879,880,64,Female,Type B,High,43,7,0,Successful
# 880,881,85,Male,Type B,High,47,4,0,Successful
# 881,882,62,Male,Type A,Medium,63,12,1,Successful
# 882,883,19,Female,Type C,High,40,9,0,Successful
# 883,884,44,Male,Type C,Low,48,2,0,Successful
# 884,885,53,Male,Type A,High,69,21,1,Complication
# 885,886,53,Male,Type A,High,99,8,0,Successful
# 886,887,43,Male,Type A,Low,67,8,0,Successful
# 887,888,60,Female,Type B,High,46,10,1,Successful
# 888,889,44,Male,Type A,High,54,18,1,Successful
# 889,890,86,Female,Type A,Medium,60,1,0,Successful
# 890,891,37,Male,Type C,Low,54,11,0,Successful
# 891,892,28,Female,Type A,Low,73,20,0,Successful
# 892,893,55,Male,Type C,Medium,63,10,0,Successful
# 893,894,23,Female,Type C,Medium,73,3,0,Successful
# 894,895,89,Male,Type B,High,55,6,0,Successful
# 895,896,40,Female,Type A,High,79,11,1,Complication
# 896,897,64,Female,Type A,High,57,16,0,Successful
# 897,898,63,Male,Type C,Medium,45,8,1,Successful
# 898,899,29,Female,Type B,Low,92,14,0,Successful
# 899,900,30,Male,Type B,High,32,2,0,Successful
# 900,901,79,Male,Type A,Medium,48,2,1,Successful
# 901,902,77,Male,Type C,Low,50,7,0,Successful
# 902,903,60,Male,Type A,Medium,97,17,0,Successful
# 903,904,85,Male,Type A,High,87,10,0,Successful
# 904,905,22,Female,Type A,Medium,82,11,0,Successful
# 905,906,54,Male,Type A,Medium,55,11,0,Successful
# 906,907,89,Male,Type C,Medium,96,15,0,Successful
# 907,908,48,Male,Type B,Medium,65,6,0,Successful
# 908,909,26,Male,Type A,Low,74,13,0,Complication
# 909,910,68,Male,Type A,High,62,5,0,Successful
# 910,911,46,Male,Type A,Low,59,19,0,Complication
# 911,912,57,Female,Type A,Medium,56,5,0,Successful
# 912,913,58,Female,Type B,Medium,56,5,0,Successful
# 913,914,28,Male,Type B,High,69,12,0,Successful
# 914,915,40,Female,Type B,High,65,10,1,Complication
# 915,916,18,Male,Type B,Low,59,11,0,Successful
# 916,917,63,Male,Type A,Low,82,11,0,Successful
# 917,918,38,Male,Type C,High,15,4,0,Successful
# 918,919,53,Male,Type B,Low,67,18,0,Successful
# 919,920,71,Male,Type B,Medium,70,14,0,Successful
# 920,921,74,Female,Type A,Medium,77,16,0,Successful
# 921,922,18,Female,Type A,High,59,7,0,Successful
# 922,923,80,Female,Type A,Low,63,12,0,Successful
# 923,924,71,Female,Type A,Medium,74,10,1,Complication
# 924,925,72,Male,Type C,High,82,15,0,Successful
# 925,926,57,Female,Type C,Low,55,15,0,Successful
# 926,927,32,Male,Type B,Medium,64,10,0,Complication
# 927,928,38,Female,Type C,Low,85,2,1,Successful
# 928,929,64,Female,Type B,Low,28,18,0,Successful
# 929,930,70,Female,Type B,Low,49,12,0,Successful
# 930,931,26,Female,Type C,High,81,6,0,Successful
# 931,932,69,Male,Type B,Medium,76,12,0,Successful
# 932,933,74,Female,Type A,High,67,2,0,Successful
# 933,934,43,Female,Type B,Medium,53,15,0,Successful
# 934,935,58,Male,Type A,Medium,46,2,0,Successful
# 935,936,52,Male,Type C,High,51,8,0,Successful
# 936,937,80,Female,Type C,High,83,11,1,Successful
# 937,938,42,Male,Type B,Medium,50,15,1,Successful
# 938,939,55,Male,Type A,Medium,61,10,0,Successful
# 939,940,19,Male,Type B,Medium,48,13,0,Successful
# 940,941,24,Female,Type C,Low,72,9,0,Successful
# 941,942,51,Male,Type B,Medium,51,9,0,Successful
# 942,943,34,Female,Type B,High,58,10,0,Successful
# 943,944,60,Female,Type A,High,34,9,0,Successful
# 944,945,76,Female,Type C,High,35,1,1,Successful
# 945,946,68,Female,Type B,Medium,60,6,0,Successful
# 946,947,71,Male,Type A,Medium,40,11,0,Successful
# 947,948,41,Female,Type B,Low,91,8,0,Successful
# 948,949,42,Male,Type A,Low,29,9,0,Successful
# 949,950,88,Female,Type A,High,47,8,1,Successful
# 950,951,69,Male,Type B,Low,60,5,0,Successful
# 951,952,87,Female,Type C,Low,54,7,1,Death
# 952,953,50,Male,Type C,High,43,8,0,Successful
# 953,954,66,Female,Type A,Medium,45,10,0,Successful
# 954,955,46,Female,Type C,Low,45,11,1,Complication
# 955,956,80,Male,Type A,Medium,55,9,0,Successful
# 956,957,39,Female,Type C,High,89,4,0,Successful
# 957,958,43,Female,Type B,High,61,3,0,Successful
# 958,959,45,Female,Type C,Low,77,22,0,Successful
# 959,960,66,Male,Type A,High,67,4,0,Successful
# 960,961,88,Female,Type A,High,76,7,0,Successful
# 961,962,66,Female,Type C,High,18,12,0,Successful
# 962,963,37,Male,Type B,Low,55,11,0,Successful
# 963,964,80,Male,Type A,Low,79,12,1,Successful
# 964,965,78,Male,Type A,Low,51,7,0,Successful
# 965,966,66,Male,Type A,High,86,11,0,Successful
# 966,967,88,Male,Type A,Medium,82,10,0,Successful
# 967,968,18,Female,Type A,High,52,8,0,Successful
# 968,969,30,Female,Type B,Low,52,11,0,Successful
# 969,970,68,Female,Type C,Medium,44,15,0,Successful
# 970,971,73,Male,Type B,Medium,50,9,0,Successful
# 971,972,79,Female,Type B,Low,41,9,0,Successful
# 972,973,49,Male,Type A,Medium,66,15,0,Successful
# 973,974,47,Male,Type B,Medium,38,14,0,Successful
# 974,975,46,Female,Type A,Low,69,17,0,Successful
# 975,976,66,Male,Type B,Medium,69,1,0,Successful
# 976,977,62,Male,Type A,Medium,35,14,0,Successful
# 977,978,47,Female,Type A,Low,83,13,0,Successful
# 978,979,33,Male,Type B,Medium,67,5,0,Successful
# 979,980,57,Male,Type B,Medium,71,11,0,Successful
# 980,981,36,Female,Type C,Medium,48,15,1,Death
# 981,982,35,Male,Type C,Medium,69,5,0,Successful
# 982,983,18,Male,Type C,Low,76,12,0,Successful
# 983,984,64,Female,Type B,High,58,14,0,Successful
# 984,985,83,Female,Type B,High,90,4,0,Successful
# 985,986,55,Female,Type A,Medium,60,9,0,Successful
# 986,987,68,Female,Type C,Low,77,11,1,Successful
# 987,988,80,Male,Type A,Low,64,6,0,Successful
# 988,989,21,Male,Type A,Medium,68,5,0,Successful
# 989,990,18,Female,Type A,High,34,9,0,Successful
# 990,991,25,Male,Type A,Medium,65,14,1,Death
# 991,992,46,Male,Type C,Low,48,13,0,Successful
# 992,993,72,Female,Type A,Low,47,5,0,Successful
# 993,994,20,Female,Type B,High,86,13,1,Successful
# 994,995,49,Male,Type B,Low,56,5,0,Successful
# 995,996,27,Female,Type B,Low,44,1,0,Successful
# 996,997,51,Female,Type C,Low,54,8,1,Successful
# 997,998,72,Female,Type A,High,40,15,0,Death
# 998,999,49,Male,Type C,Low,81,13,0,Successful
# 999,1000,67,Female,Type A,Medium,49,9,1,Successful
# 1000,1001,24,Male,Type C,High,67,7,1,Successful
# 1001,1002,25,Male,Type C,Medium,80,8,0,Successful
# 1002,1003,82,Male,Type A,Medium,52,10,0,Successful
# 1003,1004,74,Female,Type C,High,67,4,0,Successful
# 1004,1005,84,Female,Type A,Medium,44,8,0,Successful
# ...
# 4680,4681,78,Male,Type B,Medium,58,8,0,Successful
# 4681,4682,73,Female,Type C,Low,60,4,0,Complication
# 4682,4683,50,Male,Type C,High,57,18,0,Successful
# 4683,4684,62,Female,Type C,Medium,75,11,0,Successful
# 4684,4685,53,Male,Type B,High,59,14,0,Successful
# 4685,4686,37,Male,Type A,Medium,71,8,0,Successful
# 4686,4687,35,Female,Type C,Low,53,4,0,Complication
# 4687,4688,55,Male,Type C,High,62,3,0,Successful
# 4688,4689,84,Male,Type C,High,47,5,0,Successful
# 4689,4690,40,Male,Type A,Low,78,11,1,Successful
# 4690,4691,33,Male,Type A,Medium,47,12,0,Successful
# 4691,4692,76,Male,Type C,Medium,55,13,0,Successful
# 4692,4693,86,Male,Type A,High,55,2,0,Successful
# 4693,4694,85,Female,Type C,Low,54,9,0,Successful
# 4694,4695,38,Female,Type A,High,70,4,0,Successful
# 4695,4696,87,Female,Type B,High,55,12,0,Death
# 4696,4697,29,Male,Type B,Medium,80,12,0,Successful
# 4697,4698,33,Male,Type A,Medium,47,4,1,Successful
# 4698,4699,31,Male,Type B,Medium,62,14,0,Complication
# 4699,4700,78,Female,Type B,Medium,48,21,1,Complication
# 4700,4701,88,Male,Type B,Medium,66,14,1,Death
# 4701,4702,63,Female,Type C,Low,59,9,1,Successful
# 4702,4703,49,Male,Type A,High,57,8,1,Successful
# 4703,4704,32,Male,Type A,Low,77,8,0,Successful
# 4704,4705,61,Male,Type A,High,50,6,0,Successful
# 4705,4706,34,Female,Type B,Medium,68,11,0,Successful
# 4706,4707,58,Male,Type C,Low,48,4,0,Successful
# 4707,4708,71,Female,Type A,High,61,0,1,Successful
# 4708,4709,61,Male,Type B,Medium,42,11,0,Complication
# 4709,4710,22,Male,Type C,Medium,50,10,0,Death
# 4710,4711,44,Female,Type C,Low,58,7,0,Successful
# 4711,4712,60,Male,Type A,Low,87,3,0,Successful
# 4712,4713,48,Male,Type A,Low,61,11,1,Successful
# 4713,4714,34,Male,Type B,Medium,84,5,0,Successful
# 4714,4715,71,Male,Type A,High,63,9,0,Successful
# 4715,4716,79,Female,Type B,High,54,18,0,Complication
# 4716,4717,49,Female,Type C,Low,83,13,1,Successful
# 4717,4718,57,Male,Type C,High,66,3,0,Successful
# 4718,4719,30,Male,Type C,Medium,50,3,1,Successful
# 4719,4720,52,Female,Type C,High,67,10,0,Successful
# 4720,4721,22,Male,Type A,Medium,55,3,0,Successful
# 4721,4722,46,Female,Type A,Low,30,0,0,Successful
# 4722,4723,87,Male,Type B,High,74,12,0,Complication
# 4723,4724,42,Female,Type B,Medium,76,11,0,Successful
# 4724,4725,39,Female,Type B,Low,87,12,0,Death
# 4725,4726,83,Female,Type B,Low,66,11,0,Successful
# 4726,4727,62,Female,Type B,Low,56,9,0,Complication
# 4727,4728,86,Male,Type C,Low,72,6,1,Successful
# 4728,4729,89,Male,Type C,High,72,12,0,Successful
# 4729,4730,18,Female,Type C,Medium,84,17,0,Successful
# 4730,4731,61,Female,Type B,High,59,7,0,Successful
# 4731,4732,56,Female,Type C,Medium,57,4,1,Successful
# 4732,4733,71,Female,Type C,Low,49,4,1,Complication
# 4733,4734,46,Male,Type C,High,68,5,1,Successful
# 4734,4735,71,Female,Type C,Low,36,11,0,Death
# 4735,4736,33,Female,Type A,Medium,71,0,1,Successful
# 4736,4737,37,Female,Type B,Low,68,12,0,Successful
# 4737,4738,63,Female,Type B,High,68,13,1,Successful
# 4738,4739,84,Female,Type A,High,62,1,0,Death
# 4739,4740,82,Female,Type C,Medium,82,5,1,Successful
# 4740,4741,75,Female,Type C,Medium,73,10,0,Successful
# 4741,4742,70,Male,Type C,High,50,9,0,Complication
# 4742,4743,18,Female,Type B,High,51,12,0,Successful
# 4743,4744,83,Female,Type B,High,46,9,0,Successful
# 4744,4745,46,Female,Type B,High,68,16,0,Successful
# 4745,4746,87,Male,Type B,Medium,44,8,0,Successful
# 4746,4747,25,Male,Type B,High,76,5,0,Successful
# 4747,4748,46,Male,Type A,Medium,79,4,0,Complication
# 4748,4749,68,Female,Type B,High,46,13,0,Complication
# 4749,4750,50,Female,Type C,High,57,10,0,Successful
# 4750,4751,20,Female,Type B,Low,60,13,1,Successful
# 4751,4752,77,Male,Type A,Low,73,13,0,Successful
# 4752,4753,52,Female,Type C,High,84,0,0,Successful
# 4753,4754,86,Male,Type A,Medium,34,4,0,Successful
# 4754,4755,37,Male,Type C,High,55,4,0,Successful
# 4755,4756,56,Male,Type B,Low,56,5,0,Successful
# 4756,4757,21,Male,Type A,High,38,7,0,Successful
# 4757,4758,36,Male,Type C,Low,52,14,0,Successful
# 4758,4759,62,Female,Type B,High,66,15,0,Complication
# 4759,4760,60,Female,Type C,High,55,8,0,Successful
# 4760,4761,30,Male,Type A,Medium,36,8,1,Successful
# 4761,4762,30,Female,Type A,Low,103,6,0,Successful
# 4762,4763,77,Female,Type A,Low,63,10,0,Successful
# 4763,4764,74,Male,Type A,Low,61,11,1,Successful
# 4764,4765,69,Male,Type B,Medium,43,14,0,Successful
# 4765,4766,70,Female,Type C,High,63,13,0,Successful
# 4766,4767,60,Female,Type B,Medium,57,-1,0,Successful
# 4767,4768,89,Female,Type A,High,31,9,0,Complication
# 4768,4769,89,Female,Type C,Medium,43,16,0,Successful
# 4769,4770,59,Male,Type A,Medium,71,7,1,Successful
# 4770,4771,43,Female,Type B,Low,89,15,0,Successful
# 4771,4772,40,Male,Type B,Medium,65,8,0,Successful
# 4772,4773,60,Male,Type B,High,76,10,1,Successful
# 4773,4774,45,Female,Type C,Medium,57,4,1,Death
# 4774,4775,26,Female,Type C,Medium,58,4,0,Successful
# 4775,4776,37,Female,Type A,High,76,13,1,Successful
# 4776,4777,73,Male,Type C,Low,84,14,0,Successful
# 4777,4778,56,Male,Type C,High,79,10,0,Successful
# 4778,4779,68,Male,Type B,High,44,3,0,Successful
# 4779,4780,29,Male,Type A,High,58,10,0,Successful
# 4780,4781,72,Female,Type B,Medium,64,16,0,Successful
# 4781,4782,28,Male,Type A,Medium,56,18,0,Successful
# 4782,4783,43,Male,Type A,High,65,8,0,Successful
# 4783,4784,59,Female,Type C,High,72,1,0,Successful
# 4784,4785,44,Male,Type B,Low,75,14,0,Successful
# 4785,4786,28,Male,Type C,Medium,85,8,1,Successful
# 4786,4787,55,Female,Type C,Medium,55,14,0,Successful
# 4787,4788,60,Male,Type C,Medium,39,11,0,Successful
# 4788,4789,36,Male,Type A,Medium,65,5,1,Successful
# 4789,4790,81,Male,Type B,High,88,10,0,Successful
# 4790,4791,23,Male,Type B,High,52,16,0,Successful
# 4791,4792,63,Female,Type C,Low,70,9,0,Successful
# 4792,4793,59,Male,Type A,Medium,70,4,0,Successful
# 4793,4794,82,Female,Type B,Medium,62,2,0,Successful
# 4794,4795,89,Male,Type B,High,60,6,1,Successful
# 4795,4796,76,Female,Type C,Low,46,7,0,Successful
# 4796,4797,69,Female,Type A,High,25,14,0,Successful
# 4797,4798,64,Female,Type C,Medium,43,4,0,Death
# 4798,4799,24,Male,Type B,Medium,54,17,0,Successful
# 4799,4800,28,Male,Type A,Low,76,3,0,Complication
# 4800,4801,78,Male,Type C,High,58,21,0,Successful
# 4801,4802,85,Female,Type B,Medium,52,18,0,Successful
# 4802,4803,42,Male,Type C,Medium,46,10,1,Successful
# 4803,4804,29,Male,Type C,Low,69,1,0,Death
# 4804,4805,43,Male,Type C,Medium,80,9,1,Successful
# 4805,4806,29,Male,Type A,Medium,75,8,0,Successful
# 4806,4807,60,Female,Type B,High,69,3,0,Successful
# 4807,4808,68,Female,Type B,Low,37,11,0,Successful
# 4808,4809,54,Male,Type B,Low,54,5,0,Successful
# 4809,4810,63,Male,Type B,Low,89,6,1,Successful
# 4810,4811,70,Male,Type A,High,76,8,0,Death
# 4811,4812,30,Female,Type C,Low,36,7,1,Successful
# 4812,4813,71,Male,Type B,Medium,59,20,0,Successful
# 4813,4814,74,Female,Type A,Low,65,7,1,Successful
# 4814,4815,21,Female,Type C,Medium,48,12,1,Successful
# 4815,4816,66,Male,Type A,Low,25,10,0,Successful
# 4816,4817,24,Male,Type A,Low,61,11,0,Successful
# 4817,4818,28,Male,Type B,High,48,12,1,Successful
# 4818,4819,71,Female,Type B,Low,48,14,0,Successful
# 4819,4820,62,Female,Type C,Low,54,11,1,Complication
# 4820,4821,40,Male,Type C,High,57,11,0,Successful
# 4821,4822,45,Female,Type B,Medium,59,10,0,Successful
# 4822,4823,74,Male,Type A,Low,46,9,0,Successful
# 4823,4824,43,Male,Type B,Low,56,5,0,Successful
# 4824,4825,42,Female,Type C,Medium,33,9,0,Successful
# 4825,4826,71,Female,Type A,High,64,11,1,Successful
# 4826,4827,46,Female,Type A,Low,17,12,0,Successful
# 4827,4828,53,Female,Type A,High,55,10,0,Complication
# 4828,4829,31,Male,Type B,Medium,73,8,1,Successful
# 4829,4830,52,Male,Type B,Medium,44,9,0,Successful
# 4830,4831,47,Male,Type C,High,70,7,1,Death
# 4831,4832,34,Female,Type A,Medium,77,11,0,Successful
# 4832,4833,84,Male,Type A,Medium,10,8,0,Successful
# 4833,4834,47,Female,Type B,Low,57,10,0,Complication
# 4834,4835,62,Female,Type C,High,16,15,0,Successful
# 4835,4836,68,Female,Type C,Low,58,6,0,Successful
# 4836,4837,64,Male,Type A,High,59,12,0,Successful
# 4837,4838,70,Female,Type B,Low,22,10,1,Successful
# 4838,4839,81,Female,Type A,Medium,88,20,0,Complication
# 4839,4840,55,Female,Type B,High,64,8,1,Successful
# 4840,4841,81,Female,Type C,High,47,13,0,Successful
# 4841,4842,24,Female,Type A,High,81,10,1,Complication
# 4842,4843,39,Female,Type A,High,33,3,0,Successful
# 4843,4844,58,Female,Type A,Medium,41,7,0,Successful
# 4844,4845,27,Female,Type C,Medium,25,14,0,Complication
# 4845,4846,74,Female,Type A,Medium,87,7,1,Complication
# 4846,4847,24,Female,Type C,Low,64,-1,0,Successful
# 4847,4848,67,Female,Type B,Medium,69,9,0,Successful
# 4848,4849,69,Female,Type C,Low,64,4,0,Successful
# 4849,4850,50,Male,Type B,Low,68,10,0,Successful
# 4850,4851,18,Male,Type C,Medium,61,17,1,Successful
# 4851,4852,70,Female,Type C,Medium,64,13,0,Successful
# 4852,4853,77,Female,Type A,Medium,61,17,0,Successful
# 4853,4854,51,Female,Type C,Low,50,7,0,Successful
# 4854,4855,21,Male,Type A,High,59,9,1,Successful
# 4855,4856,34,Male,Type B,Medium,64,4,1,Successful
# 4856,4857,21,Male,Type B,Low,61,6,0,Death
# 4857,4858,60,Female,Type A,Low,37,5,0,Successful
# 4858,4859,21,Female,Type B,Medium,39,3,0,Successful
# 4859,4860,18,Female,Type C,Low,76,16,0,Successful
# 4860,4861,88,Female,Type A,Medium,55,0,0,Successful
# 4861,4862,67,Male,Type A,Low,68,16,0,Successful
# 4862,4863,78,Female,Type A,High,43,16,0,Successful
# 4863,4864,52,Male,Type B,Low,37,12,0,Successful
# 4864,4865,25,Male,Type B,Medium,47,4,0,Successful
# 4865,4866,41,Female,Type C,High,56,2,0,Successful
# 4866,4867,53,Male,Type C,Medium,50,7,0,Successful
# 4867,4868,67,Male,Type A,Low,79,13,0,Successful
# 4868,4869,60,Male,Type C,High,62,10,0,Death
# 4869,4870,44,Male,Type B,High,87,4,0,Complication
# 4870,4871,49,Female,Type C,Low,66,15,1,Complication
# 4871,4872,35,Female,Type B,High,23,18,0,Successful
# 4872,4873,45,Male,Type C,High,75,8,1,Successful
# 4873,4874,46,Female,Type B,High,37,10,0,Successful
# 4874,4875,33,Male,Type B,Medium,63,2,0,Successful
# 4875,4876,64,Female,Type C,Medium,48,7,0,Successful
# 4876,4877,76,Female,Type C,High,92,12,0,Successful
# 4877,4878,48,Female,Type B,Low,81,11,0,Successful
# 4878,4879,21,Female,Type A,Low,48,7,0,Successful
# 4879,4880,54,Female,Type C,Medium,58,8,1,Successful
# 4880,4881,34,Male,Type B,Low,63,7,0,Death
# 4881,4882,56,Female,Type C,High,72,8,0,Successful
# 4882,4883,65,Male,Type C,Low,60,12,0,Successful
# 4883,4884,63,Male,Type C,Medium,44,0,0,Successful
# 4884,4885,65,Female,Type C,Medium,49,9,0,Successful
# 4885,4886,56,Male,Type C,High,59,11,0,Successful
# 4886,4887,21,Female,Type A,Medium,78,7,0,Complication
# 4887,4888,47,Male,Type A,Medium,66,7,0,Successful
# 4888,4889,47,Male,Type A,Medium,48,7,0,Successful
# 4889,4890,39,Female,Type B,Low,69,7,0,Successful
# 4890,4891,83,Female,Type A,Medium,54,10,0,Successful
# 4891,4892,29,Female,Type A,Low,73,10,0,Successful
# 4892,4893,53,Female,Type B,Medium,97,0,0,Successful
# 4893,4894,35,Male,Type A,Medium,54,13,0,Successful
# 4894,4895,70,Female,Type C,Low,72,8,1,Death
# 4895,4896,88,Male,Type A,Low,48,19,1,Successful
# 4896,4897,18,Male,Type A,High,58,4,0,Successful
# 4897,4898,75,Male,Type A,High,60,5,0,Successful
# 4898,4899,23,Male,Type C,Low,57,8,0,Successful
# 4899,4900,87,Male,Type C,Medium,96,12,0,Successful
# 4900,4901,61,Male,Type C,High,55,0,0,Successful
# 4901,4902,89,Female,Type C,Low,68,5,1,Successful
# 4902,4903,41,Male,Type B,Low,31,12,0,Successful
# 4903,4904,36,Male,Type C,Medium,66,5,0,Successful
# 4904,4905,35,Male,Type C,Low,77,16,0,Successful
# 4905,4906,47,Female,Type C,High,52,7,1,Complication
# 4906,4907,59,Female,Type C,Medium,22,5,0,Successful
# 4907,4908,50,Male,Type B,Low,59,13,1,Successful
# 4908,4909,29,Female,Type A,Low,60,18,0,Successful
# 4909,4910,44,Male,Type A,Medium,70,12,0,Successful
# 4910,4911,56,Female,Type C,Medium,90,16,1,Successful
# 4911,4912,26,Male,Type C,Medium,54,18,1,Death
# 4912,4913,38,Female,Type C,High,47,5,0,Successful
# 4913,4914,46,Female,Type A,High,42,14,1,Complication
# 4914,4915,50,Female,Type A,Low,62,2,0,Successful
# 4915,4916,79,Male,Type C,Low,67,12,0,Successful
# 4916,4917,32,Male,Type A,Medium,51,9,0,Successful
# 4917,4918,19,Male,Type B,Low,71,16,0,Successful
# 4918,4919,69,Female,Type C,Low,66,15,0,Successful
# 4919,4920,61,Female,Type C,Medium,60,12,0,Successful
# 4920,4921,71,Male,Type B,High,46,11,0,Successful
# 4921,4922,35,Female,Type B,High,52,12,0,Complication
# 4922,4923,20,Male,Type A,High,23,10,0,Successful
# 4923,4924,24,Male,Type B,Low,63,9,0,Death
# 4924,4925,60,Male,Type C,Medium,60,17,0,Complication
# 4925,4926,55,Male,Type A,High,62,17,0,Successful
# 4926,4927,54,Female,Type B,Low,67,9,0,Successful
# 4927,4928,75,Female,Type A,Medium,65,11,0,Successful
# 4928,4929,50,Female,Type A,High,58,10,0,Successful
# 4929,4930,76,Male,Type A,High,60,1,0,Complication
# 4930,4931,28,Female,Type A,Medium,38,8,1,Successful
# 4931,4932,85,Male,Type B,Low,51,17,0,Successful
# 4932,4933,85,Male,Type C,Low,60,6,0,Successful
# 4933,4934,39,Male,Type C,High,48,20,0,Complication
# 4934,4935,83,Male,Type B,Medium,72,15,0,Successful
# 4935,4936,61,Male,Type C,Low,50,12,0,Complication
# 4936,4937,23,Male,Type A,Medium,63,12,1,Successful
# 4937,4938,59,Female,Type A,Medium,61,5,0,Successful
# 4938,4939,42,Female,Type A,High,71,8,0,Death
# 4939,4940,74,Female,Type B,Medium,73,17,0,Complication
# 4940,4941,72,Female,Type A,Medium,70,6,0,Successful
# 4941,4942,33,Male,Type A,Medium,28,15,1,Successful
# 4942,4943,31,Male,Type B,Low,77,3,0,Successful
# 4943,4944,56,Female,Type A,High,82,4,0,Successful
# 4944,4945,45,Female,Type A,High,52,19,0,Successful
# 4945,4946,68,Female,Type C,Medium,63,9,0,Successful
# 4946,4947,66,Female,Type B,Medium,46,7,0,Successful
# 4947,4948,26,Female,Type A,Low,30,16,0,Successful
# 4948,4949,75,Female,Type A,High,48,16,0,Successful
# 4949,4950,62,Female,Type A,Low,51,14,0,Successful
# 4950,4951,39,Female,Type A,High,54,7,0,Complication
# 4951,4952,49,Male,Type C,Low,45,8,1,Successful
# 4952,4953,86,Male,Type C,Medium,48,11,0,Successful
# 4953,4954,86,Male,Type C,Low,59,13,0,Successful
# 4954,4955,59,Male,Type C,Medium,48,7,0,Successful
# 4955,4956,70,Female,Type B,High,68,10,0,Successful
# 4956,4957,76,Male,Type A,High,70,11,0,Successful
# 4957,4958,56,Female,Type C,Medium,95,16,0,Successful
# 4958,4959,32,Male,Type A,High,76,13,0,Complication
# 4959,4960,88,Female,Type B,Low,63,2,0,Successful
# 4960,4961,46,Female,Type A,Medium,50,8,0,Successful
# 4961,4962,20,Male,Type A,High,64,5,0,Complication
# 4962,4963,27,Male,Type C,Low,64,12,0,Complication
# 4963,4964,46,Female,Type C,Low,52,14,0,Complication
# 4964,4965,52,Female,Type B,High,71,10,1,Successful
# 4965,4966,23,Female,Type A,High,39,8,0,Successful
# 4966,4967,29,Male,Type C,Low,56,10,0,Successful
# 4967,4968,55,Male,Type C,Medium,68,11,0,Successful
# 4968,4969,36,Female,Type C,High,55,6,0,Successful
# 4969,4970,84,Male,Type B,High,56,3,0,Successful
# 4970,4971,25,Female,Type A,Medium,57,0,0,Successful
# 4971,4972,25,Male,Type C,Medium,47,16,0,Successful
# 4972,4973,64,Male,Type A,High,77,12,0,Successful
# 4973,4974,21,Male,Type B,Medium,44,11,1,Successful
# 4974,4975,68,Male,Type A,Low,64,16,0,Successful
# 4975,4976,84,Male,Type C,Low,66,3,0,Successful
# 4976,4977,62,Female,Type A,Low,45,1,0,Successful
# 4977,4978,25,Female,Type A,High,61,11,0,Successful
# 4978,4979,33,Male,Type B,Medium,46,11,0,Successful
# 4979,4980,84,Female,Type B,Low,80,1,0,Complication
# 4980,4981,26,Female,Type A,Medium,42,11,0,Successful
# 4981,4982,77,Male,Type A,Low,50,7,0,Successful
# 4982,4983,88,Female,Type A,Medium,41,5,1,Successful
# 4983,4984,32,Male,Type B,Low,39,8,1,Complication
# 4984,4985,88,Female,Type B,Low,83,-2,0,Successful
# 4985,4986,58,Female,Type A,Low,68,7,1,Successful
# 4986,4987,39,Female,Type B,Low,62,6,1,Successful
# 4987,4988,41,Female,Type C,Low,50,12,1,Complication
# 4988,4989,61,Female,Type B,Low,73,9,0,Successful
# 4989,4990,18,Female,Type B,Low,47,13,0,Successful
# 4990,4991,27,Female,Type B,Low,71,-2,0,Successful
# 4991,4992,89,Male,Type C,Low,46,5,0,Successful
# 4992,4993,73,Male,Type C,Medium,50,12,0,Successful
# 4993,4994,67,Male,Type C,Medium,71,8,0,Successful
# 4994,4995,29,Male,Type A,High,72,14,0,Successful
# 4995,4996,77,Female,Type A,Low,68,0,1,Successful
# 4996,4997,43,Female,Type C,Medium,44,13,0,Successful
# 4997,4998,58,Female,Type A,Medium,53,6,0,Successful
# 4998,4999,53,Male,Type A,Medium,62,6,0,Successful
# 4999,5000,40,Male,Type A,Medium,47,14,1,Complication

# %%
# Ensure no negative waiting times or delays
df['waiting_time_days'] = df['waiting_time_days'].apply(lambda x: max(0, x))
df['scheduled_delay_days'] = df['scheduled_delay_days'].apply(lambda x: max(0, x))

# %%
# Add a column to indicate if surgery was within recommended time (e.g., 90 days)
df['within_recommended_time'] = df['waiting_time_days'] <= 90

# %%
# Calculate risk factors for unplanned emergency and death
df['risk_unplanned_emergency'] = df.apply(
    lambda row: 0.1 if row['waiting_time_days'] > 90 else 0.05, axis=1
)
df['risk_death'] = df.apply(
    lambda row: 0.15 if row['waiting_time_days'] > 90 else 0.05, axis=1
)

# %%
# Save the data to a CSV file for use in analysis
df.to_csv('synthetic_health_services_data.csv', index=False)
print("Data saved to 'synthetic_health_services_data.csv' for use in analysis.")
# Out:
# Data saved to 'synthetic_health_services_data.csv' for use in analysis.
